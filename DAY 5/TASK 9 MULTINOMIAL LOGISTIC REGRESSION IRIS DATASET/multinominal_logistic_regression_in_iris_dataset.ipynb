# %% [markdown]
# Use sklearn.datasets iris flower dataset to train your model using logistic regression. You need to figure out accuracy of your model and use that to predict different samples in your test dataset. In iris dataset there are 150 samples containing following features,
#
# - Sepal Length
# - Sepal Width
# - Petal Length
# - Petal Width
#
# Using above 4 features you will clasify a flower in one of the three categories,
#
# - Setosa
# - Versicolour
# - Virginica

# %%
from sklearn.datasets import load_iris
data=load_iris()

# %%
import pandas as pd
df=pd.DataFrame(data.data,columns=data.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data.data,data.target,test_size=0.2)
model=LogisticRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
model
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[10,  0,  0],
#        [ 0,  8,  0],
#        [ 0,  0, 12]])

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of the model: {accuracy:.2f}")
# Out:
# Accuracy of the model: 1.00

# %%
samples = [
    [5.1, 3.5, 1.4, 0.2],
    [6.0, 2.9, 4.5, 1.5],
    [6.9, 3.1, 5.4, 2.1]
]
for i, pred in enumerate(y_pred):
    print(f"Sample {i+1} Prediction:",data.target_names[pred])
# Out:
# Sample 1 Prediction: setosa
# Sample 2 Prediction: versicolor
# Sample 3 Prediction: versicolor
# Sample 4 Prediction: setosa
# Sample 5 Prediction: virginica
# Sample 6 Prediction: virginica
# Sample 7 Prediction: versicolor
# Sample 8 Prediction: versicolor
# Sample 9 Prediction: versicolor
# Sample 10 Prediction: setosa
# Sample 11 Prediction: setosa
# Sample 12 Prediction: virginica
# Sample 13 Prediction: setosa
# Sample 14 Prediction: virginica
# Sample 15 Prediction: setosa
# Sample 16 Prediction: virginica
# Sample 17 Prediction: setosa
# Sample 18 Prediction: virginica
# Sample 19 Prediction: virginica
# Sample 20 Prediction: virginica
# Sample 21 Prediction: setosa
# Sample 22 Prediction: virginica
# Sample 23 Prediction: setosa
# Sample 24 Prediction: setosa
# Sample 25 Prediction: versicolor
# Sample 26 Prediction: virginica
# Sample 27 Prediction: versicolor
# Sample 28 Prediction: virginica
# Sample 29 Prediction: versicolor
# Sample 30 Prediction: virginica
